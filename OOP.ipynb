# %% [markdown]
# ![Arabistat Logo](Arabistat_logo.png)

# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# ![alt text](https://www.creativefabrica.com/wp-content/uploads/2020/02/10/1581320332/You-can-do-it.jpg)

# %% [markdown]
# ### Prepare this lecture
#
# * For each item explain it
# * Expalin with examples as possibe
# * You can use: Youtube, google, ChatGPT, Books or Whatever you want
#
# **But**
#
# # **Don't write any thing you don't understand**

# %% [markdown]
# ### **1. Introduction to Object-Oriented Programming (OOP)**
#    - What is OOP?
#    - Principles of OOP
#      - Encapsulation
#      - Abstraction
#      - Inheritance
#      - Polymorphism
#    - Benefits of OOP
#
# ### **2. Classes and Objects**
#    - Understanding Classes and Objects
#    - Defining a Class
#    - Creating Objects from a Class
#    - The `__init__` Method (Constructor)
#    - Class Attributes vs. Instance Attributes
#    - Example: Simple Class and Object
#
# ### **3. Methods**
#    - Instance Methods
#    - Class Methods (`@classmethod`)
#    - Static Methods (`@staticmethod`)
#    - Example: Different Types of Methods
#
# ### **4. Inheritance**
#    - What is Inheritance?
#    - Implementing Inheritance in Python
#    - The `super()` Function
#    - Method Overriding
#    - Example: Inheritance in Action
#
# ### **5. Polymorphism**
#    - What is Polymorphism?
#    - Method Overloading vs. Method Overriding
#    - Polymorphism with Inheritance
#    - Example: Polymorphism in Python
#
# ### **6. Encapsulation**
#    - Understanding Encapsulation
#    - Private Attributes and Methods (`__`)
#    - Getter and Setter Methods
#    - Example: Encapsulation in Python
#
# ### **7. Abstraction**
#    - What is Abstraction?
#    - Abstract Classes and Methods (`abc` module)
#    - Example: Implementing Abstraction in Python
#
# ### **8. Special (Magic) Methods**
#    - Introduction to Magic Methods
#    - Common Magic Methods (`__str__`, `__repr__`, `__eq__`, `__len__`, etc.)
#    - Overloading Operators Using Magic Methods
#    - Example: Using Magic Methods in Python
#
# ### **9. Composition vs. Inheritance**
#    - Understanding Composition
#    - Composition vs. Inheritance: When to Use Which?
#    - Example: Composition in Python
#
# ### **10. Best Practices in OOP**
#    - Principles of SOLID
#    - Designing Reusable and Maintainable Classes
#    - Avoiding Common Pitfalls in OOP
#    - Example: Refactoring OOP Code

# %%
class Car:
    pass

# %%
class Car:
    def __init__(self,model,color,year,for_sale):#the attribute (for_sale)>>>True or False(1st letter capitalised for built in True,False)
        self.model=model#instance variable
        self.color=color
        self.year=year
        self.for_sale=for_sale

# %% [markdown]
# #introduction to OOP in python
#
#
# OOP stands for Object-Oriented Programming. It is a programming paradigm that organizes code around objects, which are instances of classes. Think of a class as a blueprint and an object as a real-world instance of that blueprint.
#
# For example, a Car class could have properties like color, make, and model and methods like start, stop, and accelerate. Each car object (like "my red Toyota Corolla") would be an instance of the Car class.
#
# Key principles of OOP include:
#
# `Encapsulation: Bundling data and the methods that operate on that data within a single unit (the class).`
#
# `Abstraction: Hiding the complex implementation details and exposing only essential features of an object.`
#
# `Inheritance: Creating new classes (subclasses) that inherit properties and methods from existing classes (parent classes).`
#
# `Polymorphism: The ability of objects of different classes to respond to the same method call in their own way.`

# %% [markdown]
# #Benefits of OOP
# Object-Oriented Programming (OOP) offers several benefits:
#
# 1. Modularity: Code is organized into reusable, self-contained objects (classes), making it easier to manage and maintain.
#
# 2. Flexibility: Objects can be easily modified and extended without affecting other parts of the code, promoting adaptability.
#
# 3. Maintainability: The structured nature of OOP code simplifies maintenance and debugging.
#
# 4. Reusability: Classes can be reused in different parts of the project or in other projects, saving development time.

# %% [markdown]
# #1-Classes and Objects
#
# object>> a bundle of related attributes(variables)(ex:temp,liq within a cup,title of a book,....)and methods(constructor)/functions,created by a class
# class>>blueprint to design the the structure of an object
#
# A class can have instance or class variable
#
# class variable>for all objects in the class
#
# instance variables>a variable within a method or function(cant be called from the class name directly) and is specific to each object in the class

# %%
class car:
    region="Italy"#class variable(outside a method(constructor))>>shared among all cars(objects)

    def __init__(self,model,color,year,for_sale):#the attribute (for_sale)>>>True or False(1st letter capitalised for built in True,False)
        self.model=model#instance variable
        self.color=color
        self.year=year
        self.for_sale=for_sale


 #the following part of the code are functions of the class that should be written in the same as the class assignment(discussed later)
    def drive(self):
        print(f"you started driving the {self.model}")
    def stop(self):
        print(f"you stopped driving the {self.model}")
    # def describe(self,model):#a function that will give details about any car without needing to print each time for each attribute(a method that reduces multiple prints)
    def describe(self, model=None):#the model= None arg. followed by if condn to modify th model name if the org info turned out
         # Method to describe the car with its attributes
        if model == None: # If no model is provided, use the instance's model
            model = self.model
        print(f"{self.color} {model} made in {self.year}.")#dont forget it must be outside the if condn but inside the def()
    # this part of the code will be added to the org cell where class car was created


    def __str__(self):# Returns a human-readable string representation of an object(can be printed)
        return f"Car(model={self.model}, color={self.color}, year={self.year})"

    def __eq__(self, other):
        if not isinstance(other, car):
            return 'not applicable'
        return (self.model == other.model and #isnt contained in the if but inside the def()
                self.color == other.color and
                self.year == other.year)


#assigning objects in the class:
car1=car("BMW","blue",2022,False)
car2=car("mercedes","red",2021,True)
car3=car("BMW","blue",2022,False)#used later(in __eg__super method)
car4=car("SSS","blue",2019,True)

# %% [markdown]
# *class and instance variables will be discussed later*

# %% [markdown]
# **note: .model , .color , .year** >>>are methods that belong to objects of a class within a function(__ init __)function with double underscore 😇
#
# therfore,they are called by .method without ()**

# %%
print(car1.model)
print(car1.color)
print("\n")
print(f"car2 color is {car2.color} and was made in {car2.year}")
print(car2.for_sale)
# Out:
# BMW
# blue
#
#
# car2 color is red and was made in 2021
# True

# %% [markdown]
# #2- Functions within a class
# **they represent what an object in the class can *do***
#
# note:since they are actual functions>>def...() therefore they are called with ()
#
# .function_name() to call the function

# %% [markdown]
# ```python
# class car:
#     ...
# #the following part of the code are functions of the class that should be written in the same as the class assignment(
#     def drive(self):
#         print(f"you started driving the {self.model}")
#     def stop(self):
#         print(f"you stopped driving the {self.model}")
#     # def describe(self,model):#a function that will give details about any car without needing to print each time for each attribute(a method that reduces multiple prints)
#     def describe(self, model=None):#the model= None arg. followed by if condn to modify th model name if the org info turned out
#          # Method to describe the car with its attributes
#         if model == None: # If no model is provided, use the instance's model
#             model = self.model
#         print(f"{self.color} {model} made in {self.year}.")#dont forget it must be outside the if condn but inside the def()
# ```

# %%
car1.drive()
car2.stop()
# Out:
# you started driving the BMW
# you stopped driving the mercedes

# %%
car1.describe()
car2.describe()
print("\n")
car1.describe(model="suzuki")
car2.describe(model="xxx")
# Out:
# blue BMW made in 2022.
# red mercedes made in 2021.
#
#
# blue suzuki made in 2022.
# red xxx made in 2021.

# %% [markdown]
# #3- Class Attributes vs. Instance Attributes
#
# ##instance variables>>within a method(constructor) of a class
# ##class variables>>outside  a method(constructor) of a class
# ## and are shared among all objects in the class
#
# ####example of class variable in the previous code is region variable(all cars{objects in the class} share the same region "Italy")
# ####while model,color,year varaiables are specific to each object in the class(have specific models ,colors and year for each of them)
# ##class variables can be called directly from the class:``` car.region```or ```car1.region``` will have same output
#
# ##while instance are called through a method for ex and is specific for each object:```car1.color ```and `car2.color` will have different outputs as longs as car1 and car2 have differnet colors

# %%
print(car1.color)
print(car2.color)
print("both same output as long as the 2 cars colors arent the same by coincidence")#color is an instance variable
print("\n")

print(car1.region)
print(car2.region)
print(car.region)
print("same output as all cars are in the same region")#region is a class variable
# Out:
# blue
# red
# both same output as long as the 2 cars colors arent the same by coincidence
#
#
# Italy
# Italy
# Italy
# same output as all cars are in the same region

# %% [markdown]
# ###vvip >> this shows that the region variable  is a class variable as it is applied to any instance in the class as u dont need to specify the object in the class u apply the method to

# %% [markdown]
# #4- Encapsulation and Abstraction

# %% [markdown]
# Encapsulation and Abstraction are key principles in Object-Oriented Programming (OOP).
#
# ##Encapsulation:
#
# 1.  Bundling: Think of it as wrapping data (attributes) and the methods that work on that data within a single unit, which is the class.
# 2. Protection: Encapsulation controls access to the internal state of an object. You can restrict direct modification of attributes from outside the class.
# 3.Implementation Hiding: It hides the internal details of how an object works, exposing only necessary interfaces.
#
#
#
#
#
# Example in your code:
#
#
#
#     #class car:
#     ... (other code) ...
#         def drive(self):
#             print(f"you started driving the {self.model}")
#         def stop(self):
#             print(f"you stopped driving the {self.model}")
#     # ... (other code) ...
#
# Here, the drive and stop methods encapsulate the logic of how a car starts and stops. The user of the car class doesn't need to worry about the internal implementation, they just call these methods.
#
# ##Abstraction:
#
# Simplification: It focuses on presenting essential features of an object while hiding the complex underlying details.
# Interface: Abstraction defines a clear contract for how an object should be used, without revealing how it fulfills that contract.
# Example (not explicitly in your code, but how you could apply it):
#
# Imagine you want to add a feature to calculate the fuel efficiency of a car. You could create an abstract method calculate_fuel_efficiency in the car class. Each subclass of car (like ElectricCar, PetrolCar) would then implement this method in their own specific way. The user interacting with these objects only needs to know about the calculate_fuel_efficiency method, not the detailed calculations behind it.
#
# `Key Differences:`
#
# `Encapsulation is about bundling data and methods together and controlling access.
# Abstraction is about simplifying the interaction with an object and hiding complexity.`

# %% [markdown]
# #5- Inheritance
#
# ###Inheritance is one of the core concepts of Object-Oriented Programming (OOP). It allows you to create a hierarchy of classes where a new class (subclass or derived class) can inherit properties and behaviors (methods) from an existing class (parent class or base class). This promotes code reusability and a well-organized class structure.

# %%
#inheritance
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        raise NotImplementedError("Subclass must implement abstract method")
        #or pass  # Placeholder for the method as it is will be used diff for each subclass
class Dog(Animal):#means that the class Dog is an inherant of class Animal attributes and methods/functions
    def speak(self):
        return f"{self.name} says Woof!"

class Cat(Animal):#means that the class Cat is an inherant of class Animal attributes and methods/functions
    def speak(self):
        return f"{self.name} says Meow!"

# Create instances of Dog and Cat  object creation
dog = Dog("husk")#Dog class has argument name inherited from class Animal
cat = Cat("Tom")#Cat class has argument name inherited from class Animal

# Call the speak method
print(dog.speak())  # Output: Buddy says Woof!
print(cat.speak())  # Output: Whiskers says Meow!
# Out:
# husk says Woof!
# Tom says Meow!

# %% [markdown]
# #6-Composition

# %% [markdown]
# ###Composition is a way to build complex objects by combining simpler objects. Think of it like building with LEGOs – you take individual bricks (smaller objects) and put them together to create a larger structure (a complex object).
#
# ###In OOP terms, a class (the complex object) contains instances of other classes (the simpler objects) as attributes. This creates a "has-a" relationship. For instance, a Car has an Engine and has Wheels.

# %%
class Engine:
    def __init__(self, horsepower):#the Engine class has horsepower attribute
        self.horsepower = horsepower

    def start(self):
        return f"Engine started with horsepower: {self.horsepower}"

class Wheel:
    def __init__(self, wheel_size):
        self.wheel_size = wheel_size

    def rotate(self):
        return  f"Wheel with size {self.wheel_size}  is rotating"

class Car:#composition simply implies that the car class has the attributes and methods of the previous classes and their functualaties
    def __init__(self, brand, horsepower, wheel_size):#this just acts a placeholders for the attributes of any object(car) created later
        self.brand = brand
        self.engine = Engine(horsepower)
        # Car has an Engine(class) of attribute(horsepower),the assigned value is the horsepower attribute which is an  arg  in def__init__ of Engine class
        self.wheels = [Wheel(wheel_size) for wheel in range(4)]  # Car has 4 Wheels

    def start_engine(self):
        return self.engine.start()

    def drive(self):
        return [wheel.rotate() for wheel in self.wheels]#to create a for loop accounting that the car has 4 wheels

# Creating a car object
my_car = Car("Toyota", 200, 16)

# Starting the engine
print(my_car.start_engine())  # Output: Engine started with horsepower: 200

# Driving the car
print(my_car.drive())  # Output: ['Wheel with size 16 is rotating', 'Wheel with size 16 is rotating', 'Wheel with size 16 is rotating', 'Wheel with size 16 is rotating']
# Out:
# Engine started with horsepower: 200
# ['Wheel with size 16  is rotating', 'Wheel with size 16  is rotating', 'Wheel with size 16  is rotating', 'Wheel with size 16  is rotating']

# %% [markdown]
# #7- Polymorphism
# Polymorphism in OOP allows objects of different classes to respond to the same method call in their own way.

# %%
class animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        pass  # Placeholder for the method as it is will be used diff for each subclass
        #or raise NotImplementedError("Subclass must implement abstract method")

class dog(animal):#means that the class Dog is an inherant of class Animal attributes and methods/functions
    def speak(self):
        return  f" {self.name} says Woof!"

class cat(animal):
    def speak(self):
        return  f" {self.name} says Meow!"

animals = [dog("husk"), cat("Tom")]#they must be filled in with name arg(attribute) that is inherited from class animal
for i in animals:
    print(i.speak())  # Output will be "Woof!" and then "Meow!"
# Out:
#  husk says Woof!
#  Tom says Meow!

# %% [markdown]
# In this example, both Dog and Cat classes inherit from Animal and override the speak method. When you call speak on each animal, it executes the version specific to that class, demonstrating polymorphism.
#
# This lets you write code that interacts with objects in a generic way, **without needing to know their specific class beforehand**.

# %% [markdown]
# #8- Special (Magic) Methods

# %% [markdown]
# Special methods (also called magic methods or dunder methods) in Python are predefined methods with names surrounded by double underscores (e.g., __init__, __str__, __add__). They provide a way to customize how your objects interact with built-in operators and functions.
#
# ###Common Magic Methods
#
# Here are a few examples of common magic methods and their uses:
#
# __init__(self, ...): Constructor method, called when an object is created.✅
#
# __str__(self): Returns a human-readable string representation of an object.
#
# __repr__(self): Returns a more developer-friendly string representation, often used for debugging.
#
# __eq__(self, other): Defines how to compare two objects for equality.
#
# __len__(self): Returns the length of an object (if applicable).
#
# __add__(self, other): Defines how to add two objects together.

# %% [markdown]
# ##9- Overloading Operators
#
# Magic methods allow you to overload operators like +, -, *, etc., so you can define how they behave with your custom objects.

# %% [markdown]
# ```python
# class(car):
#     #...(your existing code)...
#
# print(car1)#>> no readable str output
# ```

# %% [markdown]
# ```python
# class car:
#     # ... (your existing code) ...
# #this part of the code will be added to the org cell where class car was created
#     def __str__(self):
#         return f"Car(model={self.model}, color={self.color}, year={self.year})"
#
#     def __eq__(self, other):
#         if not isinstance(other, car):
#             return 'not applicable'
#         return (self.model == other.model and
#                 self.color == other.color and
#                 self.year == other.year)#isnt contained in the if but inside the def()
#
#
# print(car1)  # Output: Car(model=BMW, color=blue, year=2022)
# print(car1 == car2)  # Output: False
# print(car1==car3)    #output:True
# ```

# %%
print(car1)  # Output: Car(model=BMW, color=blue, year=2022)
#Returns a human-readable string representation of an object.
print(car1 == car2)  # Output: False
print(car1==car3)    #output:True
# Out:
# Car(model=BMW, color=blue, year=2022)
# False
# True

# %%
class car:
